# %% [markdown]
# # [대딩코딩 코딩테스트]
#
# **3월 17일 11시** 개더타운 면접
#
# https://app.gather.town/invite?token=mXLZEMGvB2RIa6XDJptA-JHtbseneRjC

# %% [markdown]
# ![KakaoTalk_20220314_224028183.jpg](attachment:KakaoTalk_20220314_224028183.jpg)

# %%
###########################################

#사용자 출력 형태로 데이터 출력하는 함수
def result():
    for list in data:
        result=print('이름:',list[0],
                     '\n나이:',list[1],
                     '\n수학점수:',list[2])
    return result

#정렬 전 원본 데이터
data=[['홍길동','16','89'],
      ['김유신','22','75'],
      ['이순신','18','98'],
      ['한석봉','17','89'],
      ['정약용','19','92']]

print('**정렬 전**')
result()
print('\n')

#정렬 후 데이터
data.sort(key=lambda x: x[0])
print('**정렬 후**')
result()

#data=[['김유신','22','75'],
#      ['이순신','18','98'],
#      ['정약용','19','92'],
#      ['한석봉','17','89'],
#      ['홍길동','16','89']]


############################################

#####[1] 정보 수정 여부를 묻는 질문#####

#반복문 - 'no'를 입력하기 전까진, 잘못된 값을 입력해도 질문 반복
for i in range(1000):
    
    want_modify=input('\n학생 정보를 수정하시겠습니까?(yes/no):')
    
    #### 1. 수정하는 경우
    if want_modify=='yes':  
        
        #####[2] 학생 이름을 묻는 질문#####
        
        #반복문 - 학생 수 만큼은 반복하도록 하여 모든 이름과 매칭 확인
        for i in range(5):

            modify_name=input('\n수정하고자 하는 학생 이름:')

            for list in data:   

                #list[0]는 개인별 데이터의 첫번째 값인 "이름"
                #데이터에 있는 이름이면 질문 계속 진행
                if modify_name==list[0]:

                    #매칭되는 데이터를 now에 저장
                    now=list

            #학생 이름을 묻는 질문에서 보기에 없는 답을 고른 경우
            if modify_name not in ['김유신','이순신','정약용','한석봉','홍길동']:
                print('\n해당 학생은 존재하지 않습니다.')
                break

            #####[3] 수정 카테고리를 묻는 질문#####    

            modify_cat=input('\n수정하고 싶은 내용(나이/수학점수):')
            if modify_cat=='나이':

                #####[4-1] 수정할 값을 묻는 질문(나이)#####
                modify_age=input('나이:')
                now[1]=modify_age
                print('\n학생 정보가 다음과 같이 수정되었습니다.',
                     '\n이름:',now[0],
                     '\n나이:',now[1],
                     '\n수학점수:',now[2])
                break

            elif modify_cat=='수학점수':

                #####[4-2] 수정할 값을 묻는 질문(수학점수)#####
                modify_score=input('수학점수:')
                now[2]=modify_score
                print('\n학생 정보가 다음과 같이 수정되었습니다.',
                     '\n이름:',now[0],
                     '\n나이:',now[1],
                     '\n수학점수:',now[2])
                break

            #수정 카테고리를 묻는 질문에서 보기에 없는 답을 고른 경우
            elif modify_cat not in ['나이','수학점수']:
                print('정확한 값을 입력하세요.')
                break
                              
    #### 2. 수정하지 않는 경우            
    if want_modify=='no':
        print('\n수정을 종료합니다.')
        result()
        break
        
    #### 3. 수정 여부를 묻는 질문에서 보기에 없는 답을 고른 경우
    elif want_modify not in ['yes','no']:
        print('\n정확한 값을 입력하세요.')
# Out:
# **정렬 전**
# 이름: 홍길동
# 나이: 16
# 수학점수: 89
# 이름: 김유신
# 나이: 22
# 수학점수: 75
# 이름: 이순신
# 나이: 18
# 수학점수: 98
# 이름: 한석봉
# 나이: 17
# 수학점수: 89
# 이름: 정약용
# 나이: 19
# 수학점수: 92
#
#
# **정렬 후**
# 이름: 김유신
# 나이: 22
# 수학점수: 75
# 이름: 이순신
# 나이: 18
# 수학점수: 98
# 이름: 정약용
# 나이: 19
# 수학점수: 92
# 이름: 한석봉
# 나이: 17
# 수학점수: 89
# 이름: 홍길동
# 나이: 16
# 수학점수: 89
#
# 학생 정보를 수정하시겠습니까?(yes/no):yes
#
# 수정하고자 하는 학생 이름:이순신
#
# 수정하고 싶은 내용(나이/수학점수):나이
# 나이:23
#
# 학생 정보가 다음과 같이 수정되었습니다.
# 이름: 이순신
# 나이: 23
# 수학점수: 98
#
# 학생 정보를 수정하시겠습니까?(yes/no):yes
#
# 수정하고자 하는 학생 이름:강감찬
#
# 해당 학생은 존재하지 않습니다.
#
# 학생 정보를 수정하시겠습니까?(yes/no):yes
#
# 수정하고자 하는 학생 이름:한석봉
#
# 수정하고 싶은 내용(나이/수학점수):영어점수
# 정확한 값을 입력하세요.
#
# 학생 정보를 수정하시겠습니까?(yes/no):yes
#
# 수정하고자 하는 학생 이름:한석봉
#
# 수정하고 싶은 내용(나이/수학점수):수학점수
# 수학점수:98
#
# 학생 정보가 다음과 같이 수정되었습니다.
# 이름: 한석봉
# 나이: 17
# 수학점수: 98
#
# 학생 정보를 수정하시겠습니까?(yes/no):아니오
#
# 정확한 값을 입력하세요.
#
# 학생 정보를 수정하시겠습니까?(yes/no):no
#
# 수정을 종료합니다.
# 이름: 김유신
# 나이: 22
# 수학점수: 75
# 이름: 이순신
# 나이: 23
# 수학점수: 98
# 이름: 정약용
# 나이: 19
# 수학점수: 92
# ...
